# %% [markdown]
# # D2C Customer Churn Project - Part 2
#
# ## Objective
# Build RFM customer segmentation and retention strategies.
#
# ## Files Included
#
# - rfm_segmentation.ipynb
# - segments.csv
# - retention_strategy.md
# - manual_review_cases.md
# - requirements.txt
#
# ## Features Used
#
# - Recency
# - Frequency
# - Monetary
# - Ticket Count
# - Campaign Count
#
# ## Segments Created
#
# - Champions
# - Loyal Customers
# - Dormant Customers
# - High Risk Unhappy
# - Low Value Customers
# - Potential Loyalists
#
# ## How to Run
#
# 1. Install requirements
#
# pip install -r requirements.txt
#
# 2. Open notebook
#
# rfm_segmentation.ipynb
#
# 3. Run all cells
